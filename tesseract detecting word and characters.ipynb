# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
img = cv2.imread(r"C:\Users\dines\Music\Work\text2.png")
img = cv2.resize(img, (1200, 400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hImg, wImg, _ = img.shape
boxes = pytesseract.image_to_boxes(img)
# print(boxes)
# for b in boxes.splitlines():
#         b = b.split(' ')
#         x, y, w, h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
#         cv2.rectangle(img, (x, hImg - y), (w, hImg - h), (0, 0, 255), 1)
#         cv2.putText(img, b[0], (x, hImg-y+15), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), 1)
# #         cv2.putText(img, ".", (x, hImg-y), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1)
# #         cv2.putText(img, ".", (w, hImg-h), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1)

# cv2.imshow("image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# T 63 332 78 363 0
# h 63 332 104 363 0
# e 106 332 121 348 0
# s 131 332 144 348 0
# t 145 332 161 363 0
# u 146 332 179 356 0
# d 175 332 191 363 0
# i 181 332 208 363 0
# o 210 332 227 348 0
# w 236 332 263 348 0
# a 254 332 269 348 0
# s 264 332 295 348 0
# f 305 326 322 363 0
# i 314 326 322 363 0
# l 323 332 331 362 0
# l 334 332 342 363 0
# e 346 332 361 348 0
# d 362 332 381 362 0
# w 391 332 417 348 0
# i 418 332 425 356 0
# t 427 332 440 356 0
# h 438 332 458 362 0
# t 469 332 481 356 0
# h 481 332 501 362 0
# e 503 332 519 348 0
# r 527 332 542 348 0
# i 545 332 552 356 0
# c 555 332 569 348 0
# h 570 332 590 362 0
# o 63 292 80 308 0
# d 81 292 100 322 0
# o 92 292 108 322 0
# r 102 292 134 308 0
# o 142 292 159 308 0
# f 160 286 173 322 0
# r 182 289 194 308 0
# o 182 292 212 308 0
# s 215 292 228 308 0
# e 230 292 245 308 0
# s 246 292 260 308 0
# , 261 289 266 296 0
# a 276 292 292 308 0
# n 293 292 313 308 0
# d 314 292 333 322 0
# w 343 292 369 308 0
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# cap = cv2.VideoCapture(0)
# cap.set(3, 640)
# cap.set(4, 480)
img = cv2.imread(r"C:\Users\dines\Music\Work\text2.png")
while True:
#     res, img = cap.read()
#     cv2.imshow("image", img)

# img = cv2.imread(r"C:\Users\dines\Music\Work\text2.png")
    img = cv2.resize(img, (1200, 1200))
    hImg, wImg, _ = img.shape
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    boxes = pytesseract.image_to_data(img)
    for x, b in enumerate(boxes.splitlines()):
        b = b.split()
        if x != 0 and len(b)>=12:
            x, y, w, h = int(b[6]), int(b[7]), int(b[8]), int(b[9])
            cv2.rectangle(img, (x, y), (w + x, h + y), (0, 0, 255), 1)
#             print(b)
    cv2.imshow("image", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
cap.release()
# Out:
# ['5', '1', '1', '1', '1', '1', '63', '112', '395', '109', '15.138016', 'Thestudlowasfled']
# ['5', '1', '1', '1', '1', '2', '400', '108', '59', '117', '0.000000', 'wth']
# ['5', '1', '1', '1', '1', '3', '469', '113', '121', '90', '0.000000', 'therich']
# ['5', '1', '1', '1', '1', '4', '639', '121', '54', '76', '49.745743', 'The']
# ['5', '1', '1', '1', '1', '5', '709', '121', '97', '76', '49.745743', 'tucio']
# ['5', '1', '1', '1', '1', '6', '819', '150', '57', '47', '58.623291', 'was']
# ['5', '1', '1', '1', '1', '7', '886', '119', '76', '78', '70.896141', 'filed']
# ['5', '1', '1', '1', '1', '8', '975', '121', '63', '76', '80.741737', 'wih']
# ['5', '1', '1', '1', '1', '9', '1049', '121', '51', '76', '80.891823', 'the']
# ['5', '1', '1', '1', '2', '1', '63', '233', '203', '108', '58.943077', 'adoro']
# ['5', '1', '1', '1', '2', '2', '204', '229', '49', '116', '59.698986', 'se']
# ['5', '1', '1', '1', '2', '3', '276', '233', '57', '90', '55.748096', 'and']
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9, 9))
plt.imshow(img, cmap="gray")

# %%
# Out:
# 'text Thestudlowasfled wth therich The tucio was filed wih the adoro se and when lh rich odor of roses, and when the summer ind stired amidst the lightsummer wid stine hes tarde areca amidst the tres ofthe garden hugh he edn teeny thre came throUgh the open catdlirlonn door the hea scent of the lc, dhe peume te orthe more delicate pertume of over thom the pink flowering thom'

# %%
import cv2
import matplotlib.pyplot as plt
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
a = []
img = cv2.imread(r"C:\Users\dines\Music\Work\text2.png")
img = cv2.resize(img, (1200, 1200))
hImg, wImg, _ = img.shape
#img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
boxes = pytesseract.image_to_data(img)
for x, b in enumerate(boxes.splitlines()):
    b = b.split()
    if len(b) == 12:
        a.append(b[11])
#     if x != 0 and len(b)>=12:
#         x, y, w, h = int(b[6]), int(b[7]), int(b[8]), int(b[9])
#         cv2.rectangle(img, (x, y), (w + x, h + y), (0, 0, 255), 1)
#         print(b)

# %%
# Out:
# 'text Thestudlowasfled wth therich The tucio was filed wih the adoro se and when lh rich odor of roses, and when the summer ind stired amidst the lightsummer wid stine hes tarde areca amidst the tres ofthe garden hugh he edn teeny thre came throUgh the open catdlirlonn door the hea scent of the lc, dhe peume te orthe more delicate pertume of over thom the pink flowering thom'
